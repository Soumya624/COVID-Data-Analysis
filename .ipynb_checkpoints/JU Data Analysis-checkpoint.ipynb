# %%
import numpy as np
from matplotlib import pyplot as plt 
covid = np.genfromtxt('Demo.csv', delimiter=',',skip_header=True)
age = covid[:,1]
plt.title("Covid Raw Data")
plt.xlabel('Age Distribution')
plt.plot(age)
plt.show()
# Out:
# abc
